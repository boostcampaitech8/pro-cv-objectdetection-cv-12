# %%
import os
import torch
import pandas as pd
from tqdm import tqdm
from pycocotools.coco import COCO

from src.core import YAMLConfig
from src.solver import TASKS
from src.misc import dist_utils
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       4 from tqdm import tqdm
#       5 from pycocotools.coco import COCO
# ----> 7 from src.core import YAMLConfig
#       8 from src.solver import TASKS
#       9 from src.misc import dist_utils
#
# ModuleNotFoundError: No module named 'src'

# %%
dfine_batch_predict_and_export(
    config="configs/dfine/custom/obs365/dfine_hgnetv2_l_obj2custom.yml",
    checkpoint="./weight/dfine_l_coco.pth",
    annotation_path="../../../dataset/test/_annotations.coco.json",
    image_dir="../../../dataset/test",
    output_csv="./output.csv",
    batch_size=8,
    threshold=0.05
)
